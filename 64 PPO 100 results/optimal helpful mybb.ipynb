# %%
AGENT_NAME = 'default_PPO_citylearn_challenge_2022_phase_2_Building_6_20_bins_100.zip'
ADVERSARY_PATH = '20 bin PPO 500 results\default_PPO_citylearn_challenge_2022_phase_2_Building_6_20_bins_500.zip'
DATASET_NAME = 'citylearn_challenge_2022_phase_2' #only action is electrical storage
ATTACK = 'Helpful myBB uninit'
INIT_DATA = 'baseline_obs'

# %%
from stable_baselines3 import PPO

from citylearn.data import DataSet

from KBMproject.mybb import BrendelBethgeAttack as BBA

import pandas as pd
import numpy as np
import os

import KBMproject.utilities as utils

# %matplotlib inline

# %% [markdown]
# Define RL agent

# %%
agent = PPO.load(path=f"{AGENT_NAME}")
print('Model loaded from storage')
# Out:
# Model loaded from storage

# %% [markdown]
# Here the adversary is a superior agent, who will improve the victim's policy. The purpose is to show how an abitrary policy can be induced on the victim

# %%
adv_path = os.path.join(os.getcwd(), '..',ADVERSARY_PATH) #get adversary from parent directory
adv_path = os.path.normpath(adv_path) #resolve '..'
adversary = PPO.load(path=adv_path)
print('Model loaded from storage')
# Out:
# Model loaded from storage

# %%
env = utils.make_discrete_env(schema=DataSet.get_schema(DATASET_NAME),  
                        action_bins=agent.action_space[0].n,
                        seed=42)

# %%
bline_kpi, bline_obs, bline_a = utils.eval_agent(env, agent)

# %%
display(bline_kpi)
# Out:
# cost_function
# annual_peak_average                      1.009986
# carbon_emissions_total                   0.913675
# cost_total                               0.820861
# daily_one_minus_load_factor_average      1.158988
# daily_peak_average                       0.944909
# electricity_consumption_total            0.929119
# monthly_one_minus_load_factor_average    0.986453
# ramping_average                          1.127882
# zero_net_energy                          1.101200
# Name: District, dtype: float64

# %%
# np.savetxt(f"baseline obs.csv", bline_obs, delimiter=",")
# np.savetxt(f"baseline actions.csv", bline_a, delimiter=",")

# %%
observation_masks = pd.Series(1, index=env.observation_names[0]).to_frame(name='all')
observation_masks['mask_time'] = observation_masks['all']
observation_masks['mask_time'][observation_masks.index.str.contains('month|day|hour')] = 0

# %%
# %%time
import logging
logging.basicConfig(level=logging.WARN)
kwargs = dict(norm=np.inf,
        targeted=True, #default false
        overshoot= 1.1,
        steps=1000,
        lr=1e-3,
        lr_decay=0.5,
        lr_num_decay=20,
        momentum=0.8,
        binary_search_steps=10,
        init_size=1_500_000, #default 100, finds sample matching the target class through iterative random search
        batch_size=1000, 
        )
kpi, obs, adv_obs, actions, targets, asr = utils.eval_targeted_attack(agent, adversary, 
                                                                        env=env, 
                                                                        ART_atk=utils.define_attack(agent, BBA, **kwargs),
                                                                        mask=observation_masks['mask_time'].to_numpy(),
                                                                        time_steps=None,
                                                                        )
# Out:
#   0%|          | 0/8759 [00:00<?, ?it/s]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   0%|          | 42/8759 [04:27<13:21:02,  5.51s/it, ASR=0.976]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%|          | 45/8759 [04:51<15:19:42,  6.33s/it, ASR=0.956]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%|          | 60/8759 [06:16<11:00:24,  4.56s/it, ASR=0.95] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%|          | 61/8759 [06:31<18:20:48,  7.59s/it, ASR=0.934]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%|          | 62/8759 [06:45<23:07:14,  9.57s/it, ASR=0.919]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%|          | 69/8759 [07:35<16:31:34,  6.85s/it, ASR=0.913]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%|          | 86/8759 [09:04<10:54:40,  4.53s/it, ASR=0.919]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#   1%
/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1022/8759 [1:49:50<16:46:07,  7.80s/it, ASR=0.86] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1024/8759 [1:50:10<17:52:37,  8.32s/it, ASR=0.859]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1025/8759 [1:50:25<21:54:48, 10.20s/it, ASR=0.859]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1050/8759 [1:52:35<10:17:48,  4.81s/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1053/8759 [1:53:05<15:48:19,  7.38s/it, ASR=0.86] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1060/8759 [1:53:47<11:00:58,  5.15s/it, ASR=0.86]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1072/8759 [1:54:57<9:59:28,  4.68s/it, ASR=0.861] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1074/8759 [1:55:23<19:07:28,  8.96s/it, ASR=0.86] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1076/8759 [1:55:46<21:00:28,  9.84s/it, ASR=0.86]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  12%|█▏        | 1079/8759 [1:56:09<16:52:02,  7.91s/it, ASR=0.859]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1103/8759 [1:58:26<11:08:34,  5.24s/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1130/8759 [2:00:48<9:49:47,  4.64s/it, ASR=0.864] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1131/8759 [2:01:03<16:10:10,  7.63s/it, ASR=0.863]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1142/8759 [2:02:03<9:51:37,  4.66s/it, ASR=0.863] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1143/8759 [2:02:18<16:20:42,  7.73s/it, ASR=0.863]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1154/8759 [2:03:26<10:30:54,  4.98s/it, ASR=0.863]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1155/8759 [2:03:40<16:26:39,  7.79s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1165/8759 [2:04:35<9:54:43,  4.70s/it, ASR=0.863] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1166/8759 [2:04:50<16:06:27,  7.64s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  13%|█▎        | 1167/8759 [2:05:04<20:13:53,  9.59s/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▎        | 1188/8759 [2:06:55<9:34:38,  4.55s/it, ASR=0.863] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▎        | 1189/8759 [2:07:09<15:57:44,  7.59s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▎        | 1192/8759 [2:07:33<14:42:21,  7.00s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▎        | 1193/8759 [2:07:47<19:26:53,  9.25s/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▎        | 1198/8759 [2:08:25<13:44:04,  6.54s/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1221/8759 [2:10:51<19:40:47,  9.40s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1226/8759 [2:11:23<12:41:40,  6.07s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1229/8759 [2:11:52<16:22:38,  7.83s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1236/8759 [2:12:35<10:58:46,  5.25s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1239/8759 [2:13:02<15:13:05,  7.29s/it, ASR=0.861]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1240/8759 [2:13:17<19:39:59,  9.42s/it, ASR=0.86] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1242/8759 [2:13:37<19:12:14,  9.20s/it, ASR=0.86]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1243/8759 [2:13:51<22:42:23, 10.88s/it, ASR=0.859]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1249/8759 [2:14:38<13:54:50,  6.67s/it, ASR=0.859]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  14%|█▍        | 1264/8759 [2:16:01<9:45:24,  4.69s/it, ASR=0.86]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  15%|█▍        | 1298/8759 [2:18:54<9:59:44,  4.82s/it, ASR=0.863] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  15%|█▍        | 1299/8759 [2:19:08<15:44:12,  7.59s/it, ASR=0.862]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  15%|█▌        | 1323/8759 [2:21:06<9:10:03,  4.44s/it, ASR=0.864] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  16%|█▌        | 1358/8759 [2:23:58<9:04:38,  4.42s/it, ASR=0.867] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  16%|█▌        | 1382/8759 [2:26:05<9:19:07,  4.55s/it, ASR=0.868] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  16%|█▌        | 1387/8759 [2:26:44<12:42:32,  6.21s/it, ASR=0.868]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1491/8759 [2:35:22<9:24:57,  4.66s/it, ASR=0.877] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1500/8759 [2:36:12<9:21:17,  4.64s/it, ASR=0.877] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1501/8759 [2:36:26<15:19:28,  7.60s/it, ASR=0.876]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1502/8759 [2:36:40<19:10:42,  9.51s/it, ASR=0.875]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1503/8759 [2:36:54<22:05:34, 10.96s/it, ASR=0.875]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1525/8759 [2:38:45<9:24:02,  4.68s/it, ASR=0.876] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  17%|█▋        | 1527/8759 [2:39:04<13:25:01,  6.68s/it, ASR=0.876]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1553/8759 [2:41:29<12:16:56,  6.14s/it, ASR=0.877]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1556/8759 [2:42:01<18:13:12,  9.11s/it, ASR=0.877]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1576/8759 [2:44:18<11:24:27,  5.72s/it, ASR=0.878]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1580/8759 [2:44:58<15:37:13,  7.83s/it, ASR=0.877]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1582/8759 [2:45:17<16:32:46,  8.30s/it, ASR=0.877]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1583/8759 [2:45:31<20:01:22, 10.04s/it, ASR=0.876]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1584/8759 [2:45:47<23:27:58, 11.77s/it, ASR=0.876]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1603/8759 [2:47:27<11:15:53,  5.67s/it, ASR=0.876]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  18%|█▊        | 1606/8759 [2:48:02<18:29:38,  9.31s/it, ASR=0.876]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▊        | 1626/8759 [2:49:55<12:43:40,  6.42s/it, ASR=0.877]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▉        | 1650/8759 [2:52:06<8:42:13,  4.41s/it, ASR=0.878] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▉        | 1670/8759 [2:53:56<8:50:55,  4.49s/it, ASR=0.879] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▉        | 1671/8759 [2:54:10<14:45:29,  7.50s/it, ASR=0.879]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▉        | 1697/8759 [2:56:32<11:21:33,  5.79s/it, ASR=0.88] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▉        | 1699/8759 [2:56:54<15:38:24,  7.98s/it, ASR=0.879]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  19%|█▉        | 1708/8759 [2:57:52<13:55:47,  7.11s/it, ASR=0.879]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  20%|██        | 1771/8759 [3:04:00<11:44:45,  6.05s/it, ASR=0.883]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1796/8759 [3:06:33<10:06:23,  5.23s/it, ASR=0.884]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1819/8759 [3:08:47<13:03:13,  6.77s/it, ASR=0.885]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1837/8759 [3:10:19<8:31:29,  4.43s/it, ASR=0.886] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1842/8759 [3:11:02<13:51:40,  7.21s/it, ASR=0.885]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1859/8759 [3:12:38<8:34:13,  4.47s/it, ASR=0.886] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1860/8759 [3:12:53<14:33:02,  7.59s/it, ASR=0.885]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██        | 1861/8759 [3:13:07<18:19:50,  9.57s/it, ASR=0.885]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██▏       | 1862/8759 [3:13:21<21:12:34, 11.07s/it, ASR=0.885]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|██▏       | 1863/8759 [3:13:36<23:28:09, 12.25s/it, ASR=0.884]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  21%|
WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  32%|███▏      | 2810/8759 [4:53:28<26:06:49, 15.80s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  32%|███▏      | 2831/8759 [4:56:16<14:19:47,  8.70s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  32%|███▏      | 2835/8759 [4:57:14<18:29:49, 11.24s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2847/8759 [4:58:51<11:06:50,  6.77s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2861/8759 [5:00:39<10:49:30,  6.61s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2873/8759 [5:02:19<14:35:04,  8.92s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2885/8759 [5:04:12<14:59:43,  9.19s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2900/8759 [5:06:26<19:55:51, 12.25s/it, ASR=0.899]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2902/8759 [5:06:57<21:06:47, 12.98s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  33%|███▎      | 2923/8759 [5:09:59<21:23:06, 13.19s/it, ASR=0.899]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▎      | 2946/8759 [5:12:56<8:41:07,  5.38s/it, ASR=0.899] WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▎      | 2947/8759 [5:13:13<14:24:15,  8.92s/it, ASR=0.899]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▎      | 2948/8759 [5:13:30<18:22:18, 11.38s/it, ASR=0.899]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▎      | 2953/8759 [5:14:17<12:58:03,  8.04s/it, ASR=0.898]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▍      | 2997/8759 [5:19:19<8:43:31,  5.45s/it, ASR=0.9]   WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▍      | 2998/8759 [5:19:38<15:07:28,  9.45s/it, ASR=0.899]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▍      | 3017/8759 [5:22:24<9:53:40,  6.20s/it, ASR=0.9]   WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  34%|███▍      | 3021/8759 [5:23:01<11:31:29,  7.23s/it, ASR=0.899]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  35%|███▍      | 3046/8759 [5:26:03<16:37:02, 10.47s/it, ASR=0.9]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  35%|███▌      | 3066/8759 [5:28:07<10:55:55,  6.91s/it, ASR=0.9]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
# ...
#  95%|█████████▍| 8302/8759 [14:39:59<1:01:41,  8.10s/it, ASR=0.91]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▍| 8304/8759 [14:40:18<1:03:20,  8.35s/it, ASR=0.91]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▍| 8308/8759 [14:40:47<49:08,  6.54s/it, ASR=0.91]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▍| 8319/8759 [14:41:47<34:24,  4.69s/it, ASR=0.91]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▍| 8320/8759 [14:42:02<55:17,  7.56s/it, ASR=0.91]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8326/8759 [14:42:57<59:00,  8.18s/it, ASR=0.91]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8327/8759 [14:43:11<1:12:11, 10.03s/it, ASR=0.91]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8328/8759 [14:43:26<1:23:03, 11.56s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8329/8759 [14:43:42<1:30:55, 12.69s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8342/8759 [14:44:52<32:33,  4.68s/it, ASR=0.909]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8343/8759 [14:45:07<53:24,  7.70s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8349/8759 [14:46:00<1:01:42,  9.03s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8350/8759 [14:46:16<1:15:09, 11.03s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8352/8759 [14:46:36<1:08:21, 10.08s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  95%|█████████▌| 8355/8759 [14:47:03<56:17,  8.36s/it, ASR=0.909]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  96%|█████████▌| 8365/8759 [14:48:02<32:50,  5.00s/it, ASR=0.909]  WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  96%|█████████▌| 8366/8759 [14:48:17<52:58,  8.09s/it, ASR=0.909]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  96%|█████████▌| 
/it, ASR=0.905]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  98%|█████████▊| 8619/8759 [15:19:04<19:18,  8.27s/it, ASR=0.905]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8628/8759 [15:19:55<10:30,  4.81s/it, ASR=0.905]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8630/8759 [15:20:14<14:35,  6.79s/it, ASR=0.905]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8634/8759 [15:20:48<16:32,  7.94s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8636/8759 [15:21:08<17:16,  8.43s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8640/8759 [15:21:37<13:01,  6.57s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8641/8759 [15:21:51<17:26,  8.87s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▊| 8643/8759 [15:22:11<17:12,  8.90s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8655/8759 [15:23:17<08:06,  4.67s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8660/8759 [15:23:55<09:45,  5.91s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8661/8759 [15:24:10<13:48,  8.45s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8662/8759 [15:24:24<16:30, 10.22s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8663/8759 [15:24:39<18:50, 11.77s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8664/8759 [15:24:53<19:43, 12.46s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8677/8759 [15:26:02<06:16,  4.59s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8678/8759 [15:26:17<10:21,  7.68s/it, ASR=0.904]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8679/8759 [15:26:32<13:17,  9.96s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8685/8759 [15:27:12<07:29,  6.07s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8686/8759 [15:27:27<10:26,  8.59s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8687/8759 [15:27:41<12:20, 10.28s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8688/8759 [15:27:55<13:32, 11.45s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8701/8759 [15:29:05<04:35,  4.75s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8706/8759 [15:29:58<07:59,  9.04s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8714/8759 [15:30:45<03:53,  5.18s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
#  99%|█████████▉| 8715/8759 [15:30:59<05:51,  7.98s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
# 100%|█████████▉| 8718/8759 [15:31:23<04:55,  7.21s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
# 100%|█████████▉| 8732/8759 [15:32:48<02:57,  6.56s/it, ASR=0.903]WARNING:KBMproject.mybb:Failed to draw a random image that is adversarial, attack failed.
# 100%|██████████| 8759/8759 [15:35:10<00:00,  6.41s/it, ASR=0.903]
# CPU times: total: 16h 48min 25s
# Wall time: 15h 35min 12s

# %%
display(kpi)
# Out:
# cost_function
# annual_peak_average                      1.102271
# carbon_emissions_total                   0.873113
# cost_total                               0.786554
# daily_one_minus_load_factor_average      0.979734
# daily_peak_average                       0.909614
# electricity_consumption_total            0.884651
# monthly_one_minus_load_factor_average    0.987908
# ramping_average                          1.125543
# zero_net_energy                          1.107857
# Name: District, dtype: float64

# %%
display(bline_kpi - kpi)
# Out:
# cost_function
# annual_peak_average                     -0.092285
# carbon_emissions_total                   0.040562
# cost_total                               0.034306
# daily_one_minus_load_factor_average      0.179255
# daily_peak_average                       0.035295
# electricity_consumption_total            0.044468
# monthly_one_minus_load_factor_average   -0.001454
# ramping_average                          0.002339
# zero_net_energy                         -0.006657
# Name: District, dtype: float64

# %%
np.savetxt(f"{ATTACK} targets.csv", targets, delimiter=",")
np.savetxt(f"{ATTACK} actions.csv", actions, delimiter=",")
np.savetxt(f"{ATTACK} adv obs.csv", adv_obs, delimiter=",")
np.savetxt(f"{ATTACK} obs.csv", obs, delimiter=",")

# %%
df_kpis = pd.concat([bline_kpi, kpi], axis='columns')

# %%
df_kpis.columns = ['trained_policy', 'induced_policy']

# %%
df_kpis.plot.barh(xlim=0.7).legend(bbox_to_anchor=(1.0, 1.05))

# %%
df_kpis.to_csv('KPIs.csv')
