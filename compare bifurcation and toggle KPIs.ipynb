# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pylab as pylab

params = {'axes.labelsize': 'xx-large',
          'xtick.labelsize': 'xx-large',
          'ytick.labelsize': 'xx-large',
          'axes.titlesize': 'xx-large',
          'legend.fontsize': 'xx-large',
          #'font.size': 16,
          'axes.titlesize': 'xx-large',
          'figure.titlesize': 'xx-large',}
pylab.rcParams.update(params)

# %%
df_sac = pd.read_csv('default SAC 500 norm space results\KPIs.csv',
                     index_col=0)

# %%
df_sac.columns[df_sac.columns.str.contains('binary|toggle')]
# Out:
# Index(['uACG_binary_SAC_05_eps', 'uACG_binary_SAC_03_eps',
#        'uACG_binary_SAC_01_eps', 'uACG_binary_SAC_03_eps_linear_half_m',
#        'uACG_binary_SAC_03_eps_2_-1_-2_1', 'untargeted_binary_myPGD_5%',
#        'toggle_binary_myPGD_5%', 'untargeted_binary_myPGD_5%_mask_time',
#        'untargeted_binary_myPGD_03_mask_time',
#        'toggle_binary_myPGD_03_mask_time',
#        'untargeted_binary_myPGD_03_mask_time_scale_solar_and_consumption_eps',
#        'untargeted_binary_myPGD_03_mask_solar_and_time_scale_consumption_eps_clipped_adv_obs',
#        'toggle_binary_myPGD_03_mask_time_and_solar_scale_consumption_eps_clipped',
#        'untargeted_binary_myPGD_03_mask_time_REscale_solar_and_consumption_eps_clipped_adv_obs'],
#       dtype='object')

# %%
df_sac.index
# Out:
# Index(['annual_peak_average', 'carbon_emissions_total', 'cost_total',
#        'daily_one_minus_load_factor_average', 'daily_peak_average',
#        'electricity_consumption_total',
#        'monthly_one_minus_load_factor_average', 'ramping_average',
#        'zero_net_energy'],
#       dtype='object', name='cost_function')

# %%
key_kpi = ['cost_total','daily_peak_average','electricity_consumption_total','ramping_average']

# %%
mask_bin = df_sac.columns[df_sac.columns.str.contains('binary_myPGD')]
mask_toggle = df_sac.columns[df_sac.columns.str.contains('toggle')]

# %%
mask_compare = [#'baseline',
                'untargeted_binary_myPGD_5%',
                'toggle_binary_myPGD_5%',
                'untargeted_binary_myPGD_03_mask_time',
                'toggle_binary_myPGD_03_mask_time',
                # 'untargeted_binary_myPGD_03_mask_solar_and_time_scale_consumption_eps_clipped_adv_obs',
                # 'toggle_binary_myPGD_03_mask_time_and_solar_scale_consumption_eps_clipped',
                ]
legend_names = [
                'eps=0.05, PGD Bifurcated',
                'eps=0.05, PGD Bifurcated, Toggle-Targeted',
                'eps=0.03 PGD Bifrucated, Masked Temporal Features',
                'eps=0.03 PGD Bifrucated, Toggle-Targeted, Masked Temporal Features',
                # 'eps=0.03 PGD Bifrucated, Masked Temporal and Solar Generation Features,\nScaled eps for Net Consumption, Clipped Observations',
                # 'eps=0.03 PGD Bifrucated, Toggle-Targeted,\nMasked Temporal and Solar Generation Features,\nScaled eps for Net Consumption, Clipped Observations',
]
names_dict = dict(zip(mask_compare, legend_names))

# %%
names_dict
# Out:
# {'untargeted_binary_myPGD_5%': 'eps=0.05, PGD Bifurcated',
#  'toggle_binary_myPGD_5%': 'eps=0.05, PGD Bifurcated, Toggle-Targeted',
#  'untargeted_binary_myPGD_03_mask_time': 'eps=0.03 PGD Bifrucated, Masked Temporal Features',
#  'toggle_binary_myPGD_03_mask_time': 'eps=0.03 PGD Bifrucated, Toggle-Targeted, Masked Temporal Features'}

# %% [markdown]
# Calculate adversarial regret

# %%
df_regret = df_sac[mask_compare].sub(df_sac['baseline'].values, axis='rows')

# %%
ax = df_regret.loc[key_kpi].rename(columns=names_dict).plot.barh(
    figsize=(10,5),
    title='Adversarial Regret for Bifurcated PGD Attacks on SAC'
)
ax.legend(
    bbox_to_anchor=(0.22, 0.48)
    )
ax.set_xlabel('Normalized KPI Difference from Clean Value')
for container in ax.containers:
    ax.bar_label(container,fmt='%.2f')
plt.tight_layout()

# %%
df_ppo = pd.read_csv(r'20 bin PPO 500 results\KPIs.csv',
                     index_col=0)

# %%
mask_ppo = df_ppo.columns[df_ppo.columns.str.contains('binary|toggle')]
df_ppo[mask_ppo]
# Out:
#                                        untargeted_binary_myPGD_05  \
# cost_function
# annual_peak_average                                      1.189929
# carbon_emissions_total                                   0.961659
# cost_total                                               0.914933
# daily_one_minus_load_factor_average                      0.983696
# daily_peak_average                                       1.140678
# electricity_consumption_total                            0.961546
# monthly_one_minus_load_factor_average                    1.014428
# ramping_average                                          1.524575
# zero_net_energy                                          1.117022
#
#                                        toggle_binary_myPGD_05  \
# cost_function
# annual_peak_average                                  1.095736
# carbon_emissions_total                               0.924140
# cost_total                                           0.852194
# daily_one_minus_load_factor_average                  0.981671
# daily_peak_average                                   1.041479
# electricity_consumption_total                        0.928078
# monthly_one_minus_load_factor_average                1.004352
# ramping_average                                      1.498865
# zero_net_energy                                      1.120943
#
#                                        untargeted_binary_myPGD_05_mask_time  \
# cost_function
# annual_peak_average                                                1.272315
# carbon_emissions_total                                             0.931910
# cost_total                                                         0.870856
# daily_one_minus_load_factor_average                                1.116276
# daily_peak_average                                                 1.073321
# electricity_consumption_total                                      0.934203
# monthly_one_minus_load_factor_average                              1.011215
# ramping_average                                                    1.422487
# zero_net_energy                                                    1.115737
#
#                                        untargeted_binary_myPGD_03_mask_time  \
# cost_function
# annual_peak_average                                                1.182043
# carbon_emissions_total                                             0.897824
# cost_total                                                         0.824304
# daily_one_minus_load_factor_average                                0.998957
# daily_peak_average                                                 0.961169
# electricity_consumption_total                                      0.904310
# monthly_one_minus_load_factor_average                              0.998609
# ramping_average                                                    1.242503
# zero_net_energy                                                    1.110701
#
#                                        untargeted_binary_myPGD_03_mask_time_scale_solar_and_consumption_eps
# cost_function
# annual_peak_average                                                             1.420853
# carbon_emissions_total                                                          0.896728
# cost_total                                                                      0.822337
# daily_one_minus_load_factor_average                                             1.010155
# daily_peak_average                                                              0.954841
# electricity_consumption_total                                                   0.903735
# monthly_one_minus_load_factor_average                                           0.992092
# ramping_average                                                                 1.236180
# zero_net_energy                                                                 1.110859

# %% [markdown]
# It appears that the toggle requires a larger adv budget than simple bifurcation to be effective

# %%
df_regret_ppo = df_ppo[['untargeted_binary_myPGD_05','toggle_binary_myPGD_05']].sub(df_ppo['baseline'].values, axis='rows')

# %%
ax = df_regret_ppo.loc[key_kpi].plot.barh(
    figsize=(10,3),
    title='Adversarial Regret for Bifurcated PGD Attacks on PPO'
)
ax.legend(['eps=0.05, PGD Bifurcated',
            'eps=0.05, PGD Bifurcated, Toggle-Targeted',]
    #bbox_to_anchor=(0.22, 0.48)
    )
ax.set_xlabel('Normalized KPI Difference from Clean Value')
for container in ax.containers:
    ax.bar_label(container,fmt='%.2f')
plt.tight_layout()

# %% [markdown]
# Bifucated PGD had an ASR of 62.8%, while it was 36% for the toggled attack

# %%
fig = plt.figure(figsize=[20,10],)
fig.suptitle('Adversarial Regret for Bifurcated PGD Attacks on SAC and Discrete PPO')
fig.supxlabel('Normalized KPI Difference from Clean Values',
              fontsize='x-large')
fig.supylabel('cost_function',
              fontsize='x-large')

plt.subplot(2, 1, 1) #(row, col, plt#)
ax = df_regret.loc[key_kpi].rename(columns=names_dict).plot.barh(
    title='Adversarial Regret for Bifurcated PGD Attacks on SAC',
    ax=plt.gca(),
)
ax.legend(
    )
ax.set_ylabel(None)
for container in ax.containers:
    ax.bar_label(container,fmt='%.2f')

plt.subplot(2, 1, 2) #(row, col, plt#)
ax = df_regret_ppo.loc[key_kpi].plot.barh(
    title='Adversarial Regret for Bifurcated PGD Attacks on PPO',
    ax=plt.gca(),
)
ax.legend(['eps=0.05, PGD Bifurcated',
            'eps=0.05, PGD Bifurcated, Toggle-Targeted',]
    )
ax.set_ylabel(None)
for container in ax.containers:
    ax.bar_label(container,fmt='%.2f')

plt.tight_layout()
