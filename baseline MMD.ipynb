# %% [markdown]
# Tutorial for MMD with the TorchDrift library: https://towardsai.net/p/machine-learning/drift-detection-using-torchdrift-for-tabular-and-time-series-data
#
# more documentation on TorchDrift MMD: https://torchdrift.org/notebooks/note_on_mmd.html

# %%
RED = "\033[91m"
AUTO = "\033[0m"

# %%
import pandas as pd
import torch
import numpy as np
from tqdm import tqdm
import torchdrift.detectors as detectors
from joblib import Parallel, delayed

# %%
DATA_PATH = r'default SAC 500 norm space results\baseline_obs-a.csv'
SAVE_DIR = 'default SAC 500 norm space results' + '/'
SEGMENT_NAME = 'day'
SEGMENTS = 365
BOOTSTRAP = 10_000
PVAL = 0.05
JOBS = 48
SAVE_NAME = f'{SEGMENT_NAME}ly baseline MMD'

# %%
df_data = pd.read_csv(DATA_PATH,
                      index_col=0,
                      usecols = lambda x: x != 'actions', #excludes a col
                      )

# %% [markdown]
# ##### On the (Statistical) Detection of Adversarial Examples
#
# **Two-sample hypothesis testing** — As stated before, the test we chose is appropriate to handle high dimensional inputs and small sample sizes. We compute the biased estimate of MMD using a **Gaussian kernel**, and then apply **10 000 bootstrapping iterations** to estimate the distributions. Based on this, we compute the **pvalue** and compare it to the threshold, in our experiments **0.05**. For samples of **legitimate data, the observed p-value should always be very high**, whereas for sample sets containing adversarial examples, we expect it to be low—since they are sampled from a different distribution and thus the hypothesis should be rejected. The test is more likely to detect a difference in two distributions when it considers samples of large size (i.e., the sample contains more inputs from the distribution).

# %%
kernel = detectors.mmd.GaussianKernel()

# %%
def show_results(results): #results is a tuple of (action (mmd,pval))
    for result in results:
        if result[1][1] > PVAL:
            dist = 'identical'
            colour = AUTO
        else:
            dist = 'distinct'
            colour = RED
        print(f'For {SEGMENT_NAME} {result[0]}: mmd:{result[1][0]:.5f}, p-value:{result[1][1]}, {colour}distributions are {dist}{AUTO}')

# %% [markdown]
# Time series splits

# %%
samples = np.array_split(df_data.to_numpy(), SEGMENTS) #using sklearn time series split, which returns indeces, might let me load all the data as a cuda tensor, instead of transfering it sequentially.

# %% [markdown]
# Compares one segment to the next

# %%
def process_action(i, dist1, dist2):
    return i, detectors.kernel_mmd(torch.from_numpy(dist1).to('cuda'), 
                                  torch.from_numpy(dist2).to('cuda'), #excludes i
                                  n_perm=BOOTSTRAP,
                                  kernel=kernel)

results = Parallel(n_jobs=JOBS, #set n_jobs so you don't run out of vram, 
            prefer='threads' #threads are like 8 times faster than multiprocessing, less overhead and the cpu work is negligable
            )(delayed(process_action)(i, samples[i], samples[i + 1]) for i in tqdm(range(SEGMENTS - 1))) #offset  of 1 avoids comparing the 0th segment to the slice of [:0], which is empty
                #a slice of samples is a list, so we concatinate them into a simgle array
show_results(results)
# Out:
# 100%|██████████| 364/364 [20:17<00:00,  3.34s/it]
# For week 0: mmd:0.10257, p-value:0.16279999911785126, distributions are identical
# For week 1: mmd:0.10587, p-value:0.13539999723434448, distributions are identical
# For week 2: mmd:0.11805, p-value:0.06659999489784241, distributions are identical
# For week 3: mmd:0.10113, p-value:0.1850999891757965, distributions are identical
# For week 4: mmd:0.10680, p-value:0.14489999413490295, distributions are identical
# For week 5: mmd:0.10473, p-value:0.17299999296665192, distributions are identical
# For week 6: mmd:0.13454, p-value:0.03689999878406525, distributions are distinct
# For week 7: mmd:0.07986, p-value:0.5388999581336975, distributions are identical
# For week 8: mmd:0.07984, p-value:0.5317000150680542, distributions are identical
# For week 9: mmd:0.08249, p-value:0.4777999818325043, distributions are identical
# For week 10: mmd:0.08545, p-value:0.41029998660087585, distributions are identical
# For week 11: mmd:0.09717, p-value:0.23189999163150787, distributions are identical
# For week 12: mmd:0.10046, p-value:0.19020000100135803, distributions are identical
# For week 13: mmd:0.14462, p-value:0.020399998873472214, distributions are distinct
# For week 14: mmd:0.08314, p-value:0.45979997515678406, distributions are identical
# For week 15: mmd:0.08006, p-value:0.5342999696731567, distributions are identical
# For week 16: mmd:0.07975, p-value:0.5471999645233154, distributions are identical
# For week 17: mmd:0.10570, p-value:0.14800000190734863, distributions are identical
# For week 18: mmd:0.15391, p-value:0.008899999782443047, distributions are distinct
# For week 19: mmd:0.11516, p-value:0.09529999643564224, distributions are identical
# For week 20: mmd:0.16398, p-value:0.00559999980032444, distributions are distinct
# For week 21: mmd:0.08447, p-value:0.43369999527931213, distributions are identical
# For week 22: mmd:0.08409, p-value:0.4430999755859375, distributions are identical
# For week 23: mmd:0.08951, p-value:0.3425999879837036, distributions are identical
# For week 24: mmd:0.10365, p-value:0.1664000004529953, distributions are identical
# For week 25: mmd:0.12063, p-value:0.06499999761581421, distributions are identical
# For week 26: mmd:0.11709, p-value:0.07559999823570251, distributions are identical
# For week 27: mmd:0.15929, p-value:0.005399999674409628, distributions are distinct
# For week 28: mmd:0.08824, p-value:0.3684999942779541, distributions are identical
# For week 29: mmd:0.08420, p-value:0.43549999594688416, distributions are identical
# For week 30: mmd:0.09711, p-value:0.2352999895811081, distributions are identical
# For week 31: mmd:0.09540, p-value:0.2556999921798706, distributions are identical
# For week 32: mmd:0.12923, p-value:0.03610000014305115, distributions are distinct
# For week 33: mmd:0.11826, p-value:0.07689999788999557, distributions are identical
# For week 34: mmd:0.14691, p-value:0.013199999928474426, distributions are distinct
# For week 35: mmd:0.08751, p-value:0.38449999690055847, distributions are identical
# For week 36: mmd:0.07941, p-value:0.5367000102996826, distributions are identical
# For week 37: mmd:0.08443, p-value:0.4277999997138977, distributions are identical
# For week 38: mmd:0.09718, p-value:0.23169998824596405, distributions are identical
# For week 39: mmd:0.10462, p-value:0.15609999001026154, distributions are identical
# For week 40: mmd:0.09878, p-value:0.21739999949932098, distributions are identical
# For week 41: mmd:0.14821, p-value:0.011299999430775642, distributions are distinct
# For week 42: mmd:0.10516, p-value:0.13930000364780426, distributions are identical
# For week 43: mmd:0.10849, p-value:0.11409999430179596, distributions are identical
# For week 44: mmd:0.09226, p-value:0.2953999936580658, distributions are identical
# For week 45: mmd:0.09976, p-value:0.20889998972415924, distributions are identical
# For week 46: mmd:0.09356, p-value:0.2759000062942505, distributions are identical
# For week 47: mmd:0.09351, p-value:0.2751999795436859, distributions are identical
# For week 48: mmd:0.14781, p-value:0.017500000074505806, distributions are distinct
# For week 49: mmd:0.08586, p-value:0.4120999872684479, distributions are identical
# For week 50: mmd:0.08669, p-value:0.4016999900341034, distributions are identical
# For week 51: mmd:0.09800, p-value:0.2303999960422516, distributions are identical
# For week 52: mmd:0.12058, p-value:0.05729999765753746, distributions are identical
# For week 53: mmd:0.13055, p-value:0.03889999911189079, distributions are distinct
# For week 54: mmd:0.11736, p-value:0.08049999922513962, distributions are identical
# For week 55: mmd:0.19970, p-value:0.00019999999494757503, distributions are distinct
# For week 56: mmd:0.10836, p-value:0.11699999868869781, distributions are identical
# For week 57: mmd:0.09469, p-value:0.2590999901294708, distributions are identical
# For week 58: mmd:0.10309, p-value:0.1639000028371811, distributions are identical
# For week 59: mmd:0.09981, p-value:0.19280000030994415, distributions are identical
# For week 60: mmd:0.11330, p-value:0.09449999779462814, distributions are identical
# For week 61: mmd:0.12848, p-value:0.03579999879002571, distributions are distinct
# For week 62: mmd:0.18042, p-value:0.0010999999940395355, distributions are distinct
# For week 63: mmd:0.08084, p-value:0.512499988079071, distributions are identical
# For week 64: mmd:0.09737, p-value:0.22929999232292175, distributions are identical
# For week 65: mmd:0.11384, p-value:0.09049999713897705, distributions are identical
# For week 66: mmd:0.09621, p-value:0.24650000035762787, distributions are identical
# For week 67: mmd:0.08777, p-value:0.38339999318122864, distributions are identical
# For week 68: mmd:0.09862, p-value:0.2166999876499176, distributions are identical
# For week 69: mmd:0.15318, p-value:0.008599999360740185, distributions are distinct
# For week 70: mmd:0.09092, p-value:0.31630000472068787, distributions are identical
# For week 71: mmd:0.10856, p-value:0.12469999492168427, distributions are identical
# For week 72: mmd:0.11577, p-value:0.07689999788999557, distributions are identical
# For week 73: mmd:0.10431, p-value:0.1614999920129776, distributions are identical
# For week 74: mmd:0.13202, p-value:0.03019999898970127, distributions are distinct
# For week 75: mmd:0.11673, p-value:0.08179999887943268, distributions are identical
# For week 76: mmd:0.14218, p-value:0.018799999728798866, distributions are distinct
# For week 77: mmd:0.14556, p-value:0.011399999260902405, distributions are distinct
# For week 78: mmd:0.14935, p-value:0.007199999876320362, distributions are distinct
# For week 79: mmd:0.12834, p-value:0.03370000049471855, distributions are distinct
# For week 80: mmd:0.10719, p-value:0.13939999043941498, distributions are identical
# For week 81: mmd:0.12214, p-value:0.05819999799132347, distributions are identical
# For week 82: mmd:0.13429, p-value:0.023099999874830246, distributions are distinct
# For week 83: mmd:0.18546, p-value:9.999999747378752e-05, distributions are distinct
# For week 84: mmd:0.18267, p-value:0.0010999999940395355, distributions are distinct
# For week 85: mmd:0.10055, p-value:0.19119998812675476, distributions are identical
# For week 86: mmd:0.11135, p-value:0.10170000046491623, distributions are identical
# For week 87: mmd:0.11573, p-value:0.0851999968290329, distributions are identical
# For week 88: mmd:0.17010, p-value:0.0015999999595806003, distributions are distinct
# For week 89: mmd:0.11268, p-value:0.09649999439716339, distributions are identical
# For week 90: mmd:0.24397, p-value:0.0, distributions are distinct
# For week 91: mmd:0.22559, p-value:0.0, distributions are distinct
# For week 92: mmd:0.15980, p-value:0.004600000102072954, distributions are distinct
# For week 93: mmd:0.11310, p-value:0.09389999508857727, distributions are identical
# For week 94: mmd:0.14123, p-value:0.019899999722838402, distributions are distinct
# For week 95: mmd:0.12405, p-value:0.048899997025728226, distributions are distinct
# For week 96: mmd:0.13703, p-value:0.019600000232458115, distributions are distinct
# For week 97: mmd:0.14860, p-value:0.012799999676644802, distributions are distinct
# For week 98: mmd:0.09822, p-value:0.21779999136924744, distributions are identical
# For week 99: mmd:0.13249, p-value:0.030799999833106995, distributions are distinct
# For week 100: mmd:0.13996, p-value:0.0210999995470047, distributions are distinct
# For week 101: mmd:0.10849, p-value:0.1265999972820282, distributions are identical
# For week 102: mmd:0.15642, p-value:0.004799999762326479, distributions are distinct
# For week 103: mmd:0.19746, p-value:0.00019999999494757503, distributions are distinct
# For week 104: mmd:0.23091, p-value:0.0, distributions are distinct
# For week 105: mmd:0.10548, p-value:0.1451999992132187, distributions are identical
# For week 106: mmd:0.13127, p-value:0.031300000846385956, distributions are distinct
# For week 107: mmd:0.13219, p-value:0.026799999177455902, distributions are distinct
# For week 108: mmd:0.18923, p-value:0.00039999998989515007, distributions are distinct
# For week 109: mmd:0.16000, p-value:0.0044999998062849045, distributions are distinct
# For week 110: mmd:0.15556, p-value:0.006099999882280827, distributions are distinct
# For week 111: mmd:0.16360, p-value:0.002899999963119626, distributions are distinct
# For week 112: mmd:0.12591, p-value:0.044199999421834946, distributions are distinct
# For week 113: mmd:0.08858, p-value:0.3513000011444092, distributions are identical
# For week 114: mmd:0.11239, p-value:0.1022999957203865, distributions are identical
# For week 115: mmd:0.14611, p-value:0.01269999984651804, distributions are distinct
# For week 116: mmd:0.11209, p-value:0.10559999942779541, distributions are identical
# For week 117: mmd:0.11001, p-value:0.11569999903440475, distributions are identical
# For week 118: mmd:0.17135, p-value:0.0008999999845400453, distributions are distinct
# For week 119: mmd:0.11021, p-value:0.1062999963760376, distributions are identical
# For week 120: mmd:0.18359, p-value:0.000699999975040555, distributions are distinct
# For week 121: mmd:0.18802, p-value:0.0004999999655410647, distributions are distinct
# For week 122: mmd:0.11860, p-value:0.06589999794960022, distributions are identical
# For week 123: mmd:0.15619, p-value:0.005499999970197678, distributions are distinct
# For week 124: mmd:0.16557, p-value:0.0026000000070780516, distributions are distinct
# For week 125: mmd:0.21769, p-value:0.0, distributions are distinct
# For week 126: mmd:0.14117, p-value:0.014499999582767487, distributions are distinct
# For week 127: mmd:0.15562, p-value:0.005399999674409628, distributions are distinct
# For week 128: mmd:0.10597, p-value:0.13849999010562897, distributions are identical
# For week 129: mmd:0.09869, p-value:0.21699999272823334, distributions are identical
# For week 130: mmd:0.11403, p-value:0.08879999816417694, distributions are identical
# For week 131: mmd:0.09839, p-value:0.22349999845027924, distributions are identical
# For week 132: mmd:0.15119, p-value:0.00839999970048666, distributions are distinct
# For week 133: mmd:0.11740, p-value:0.07580000162124634, distributions are identical
# For week 134: mmd:0.10752, p-value:0.13509999215602875, distributions are identical
# For week 135: mmd:0.10522, p-value:0.15519998967647552, distributions are identical
# For week 136: mmd:0.11221, p-value:0.10130000114440918, distributions are identical
# For week 137: mmd:0.10838, p-value:0.12629999220371246, distributions are identical
# For week 138: mmd:0.09979, p-value:0.203699991106987, distributions are identical
# For week 139: mmd:0.17531, p-value:0.0009999999310821295, distributions are distinct
# For week 140: mmd:0.11464, p-value:0.08859999477863312, distributions are identical
# For week 141: mmd:0.11627, p-value:0.06939999759197235, distributions are identical
# For week 142: mmd:0.13617, p-value:0.01860000006854534, distributions are distinct
# For week 143: mmd:0.14190, p-value:0.01209999993443489, distributions are distinct
# For week 144: mmd:0.12790, p-value:0.03179999813437462, distributions are distinct
# For week 145: mmd:0.11739, p-value:0.0697999969124794, distributions are identical
# For week 146: mmd:0.17928, p-value:0.0007999999797903001, distributions are distinct
# For week 147: mmd:0.13063, p-value:0.026799999177455902, distributions are distinct
# For week 148: mmd:0.15148, p-value:0.007699999958276749, distributions are distinct
# For week 149: mmd:0.10737, p-value:0.12849999964237213, distributions are identical
# For week 150: mmd:0.14413, p-value:0.013199999928474426, distributions are distinct
# For week 151: mmd:0.15513, p-value:0.004900000058114529, distributions are distinct
# For week 152: mmd:0.16870, p-value:0.00279999990016222, distributions are distinct
# For week 153: mmd:0.25421, p-value:0.0, distributions are distinct
# For week 154: mmd:0.22049, p-value:0.0, distributions are distinct
# For week 155: mmd:0.12768, p-value:0.039799999445676804, distributions are distinct
# For week 156: mmd:0.15764, p-value:0.004799999762326479, distributions are distinct
# For week 157: mmd:0.11983, p-value:0.06830000132322311, distributions are identical
# For week 158: mmd:0.14387, p-value:0.015699999406933784, distributions are distinct
# For week 159: mmd:0.16988, p-value:0.0015999999595806003, distributions are distinct
# For week 160: mmd:0.15513, p-value:0.00699999975040555, distributions are distinct
# For week 161: mmd:0.10140, p-value:0.18219999969005585, distributions are identical
# For week 162: mmd:0.11562, p-value:0.07229999452829361, distributions are identical
# For week 163: mmd:0.13207, p-value:0.02419999986886978, distributions are distinct
# For week 164: mmd:0.09834, p-value:0.2232999950647354, distributions are identical
# For week 165: mmd:0.11429, p-value:0.08749999850988388, distributions are identical
# For week 166: mmd:0.08766, p-value:0.3772999942302704, distributions are identical
# For week 167: mmd:0.17154, p-value:0.001999999862164259, distributions are distinct
# For week 168: mmd:0.14395, p-value:0.013100000098347664, distributions are distinct
# For week 169: mmd:0.14613, p-value:0.013399999588727951, distributions are distinct
# For week 170: mmd:0.16931, p-value:0.0030999998562037945, distributions are distinct
# For week 171: mmd:0.13837, p-value:0.018799999728798866, distributions are distinct
# For week 172: mmd:0.13386, p-value:0.027699999511241913, distributions are distinct
# For week 173: mmd:0.10720, p-value:0.1290999948978424, distributions are identical
# For week 174: mmd:0.19107, p-value:9.999999747378752e-05, distributions are distinct
# For week 175: mmd:0.18932, p-value:0.00039999998989515007, distributions are distinct
# For week 176: mmd:0.13290, p-value:0.025299999862909317, distributions are distinct
# For week 177: mmd:0.15810, p-value:0.0038999998942017555, distributions are distinct
# For week 178: mmd:0.12929, p-value:0.03889999911189079, distributions are distinct
# For week 179: mmd:0.13186, p-value:0.030299998819828033, distributions are distinct
# For week 180: mmd:0.13215, p-value:0.03319999948143959, distributions are distinct
# For week 181: mmd:0.15035, p-value:0.010900000110268593, distributions are distinct
# For week 182: mmd:0.09556, p-value:0.2491999864578247, distributions are identical
# For week 183: mmd:0.10368, p-value:0.1656000018119812, distributions are identical
# For week 184: mmd:0.10404, p-value:0.1573999971151352, distributions are identical
# For week 185: mmd:0.19360, p-value:0.00019999999494757503, distributions are distinct
# For week 186: mmd:0.20968, p-value:0.0, distributions are distinct
# For week 187: mmd:0.32349, p-value:0.0, distributions are distinct
# For week 188: mmd:0.21361, p-value:0.0, distributions are distinct
# For week 189: mmd:0.11802, p-value:0.06719999760389328, distributions are identical
# For week 190: mmd:0.13650, p-value:0.01850000023841858, distributions are distinct
# For week 191: mmd:0.14179, p-value:0.013399999588727951, distributions are distinct
# For week 192: mmd:0.19768, p-value:0.00019999999494757503, distributions are distinct
# For week 193: mmd:0.12506, p-value:0.042500000447034836, distributions are distinct
# For week 194: mmd:0.18466, p-value:0.00019999999494757503, distributions are distinct
# For week 195: mmd:0.20155, p-value:0.0004999999655410647, distributions are distinct
# For week 196: mmd:0.10926, p-value:0.12520000338554382, distributions are identical
# For week 197: mmd:0.09113, p-value:0.3271999955177307, distributions are identical
# For week 198: mmd:0.09307, p-value:0.28769999742507935, distributions are identical
# For week 199: mmd:0.11486, p-value:0.085999995470047, distributions are identical
# For week 200: mmd:0.08895, p-value:0.36730000376701355, distributions are identical
# For week 201: mmd:0.08596, p-value:0.4080999791622162, distributions are identical
# For week 202: mmd:0.14121, p-value:0.01679999940097332, distributions are distinct
# For week 203: mmd:0.09302, p-value:0.2920999825000763, distributions are identical
# For week 204: mmd:0.11536, p-value:0.0876999944448471, distributions are identical
# For week 205: mmd:0.15340, p-value:0.008599999360740185, distributions are distinct
# For week 206: mmd:0.09768, p-value:0.22439999878406525, distributions are identical
# For week 207: mmd:0.11600, p-value:0.07840000092983246, distributions are identical
# For week 208: mmd:0.13237, p-value:0.029199998825788498, distributions are distinct
# For week 209: mmd:0.20907, p-value:0.00029999998514540493, distributions are distinct
# For week 210: mmd:0.19613, p-value:9.999999747378752e-05, distributions are distinct
# For week 211: mmd:0.18171, p-value:0.00139999995008111, distributions are distinct
# For week 212: mmd:0.11370, p-value:0.09439999610185623, distributions are identical
# For week 213: mmd:0.12428, p-value:0.048899997025728226, distributions are distinct
# For week 214: mmd:0.16675, p-value:0.0023999998811632395, distributions are distinct
# For week 215: mmd:0.23122, p-value:0.0, distributions are distinct
# For week 216: mmd:0.24482, p-value:0.0, distributions are distinct
# For week 217: mmd:0.12408, p-value:0.04910000041127205, distributions are distinct
# For week 218: mmd:0.12092, p-value:0.0575999990105629, distributions are identical
# For week 219: mmd:0.10391, p-value:0.15230000019073486, distributions are identical
# For week 220: mmd:0.09327, p-value:0.28129997849464417, distributions are identical
# For week 221: mmd:0.10499, p-value:0.1509999930858612, distributions are identical
# For week 222: mmd:0.13583, p-value:0.02199999988079071, distributions are distinct
# For week 223: mmd:0.20077, p-value:0.000699999975040555, distributions are distinct
# For week 224: mmd:0.12545, p-value:0.03909999877214432, distributions are distinct
# For week 225: mmd:0.12224, p-value:0.057999998331069946, distributions are identical
# For week 226: mmd:0.09693, p-value:0.2369999885559082, distributions are identical
# For week 227: mmd:0.10328, p-value:0.16509999334812164, distributions are identical
# For week 228: mmd:0.13023, p-value:0.029999999329447746, distributions are distinct
# For week 229: mmd:0.12910, p-value:0.035099998116493225, distributions are distinct
# For week 230: mmd:0.16507, p-value:0.002699999837204814, distributions are distinct
# For week 231: mmd:0.16685, p-value:0.00139999995008111, distributions are distinct
# For week 232: mmd:0.18360, p-value:0.00039999998989515007, distributions are distinct
# For week 233: mmd:0.12968, p-value:0.03139999881386757, distributions are distinct
# For week 234: mmd:0.10148, p-value:0.1833999902009964, distributions are identical
# For week 235: mmd:0.10998, p-value:0.1062999963760376, distributions are identical
# For week 236: mmd:0.11881, p-value:0.06909999996423721, distributions are identical
# For week 237: mmd:0.17499, p-value:0.0016999999061226845, distributions are distinct
# For week 238: mmd:0.12264, p-value:0.05939999967813492, distributions are identical
# For week 239: mmd:0.12110, p-value:0.06459999829530716, distributions are identical
# For week 240: mmd:0.10082, p-value:0.1889999955892563, distributions are identical
# For week 241: mmd:0.14706, p-value:0.014299999922513962, distributions are distinct
# For week 242: mmd:0.17941, p-value:0.0011999999405816197, distributions are distinct
# For week 243: mmd:0.11321, p-value:0.0965999960899353, distributions are identical
# For week 244: mmd:0.13515, p-value:0.032099999487400055, distributions are distinct
# For week 245: mmd:0.11158, p-value:0.11319999396800995, distributions are identical
# For week 246: mmd:0.10963, p-value:0.12839999794960022, distributions are identical
# For week 247: mmd:0.12908, p-value:0.04319999739527702, distributions are distinct
# For week 248: mmd:0.10586, p-value:0.1444000005722046, distributions are identical
# For week 249: mmd:0.10773, p-value:0.1281999945640564, distributions are identical
# For week 250: mmd:0.12218, p-value:0.05609999969601631, distributions are identical
# For week 251: mmd:0.19213, p-value:0.0005999999702908099, distributions are distinct
# For week 252: mmd:0.10464, p-value:0.1598999947309494, distributions are identical
# For week 253: mmd:0.09007, p-value:0.33469998836517334, distributions are identical
# For week 254: mmd:0.10865, p-value:0.13419999182224274, distributions are identical
# For week 255: mmd:0.10059, p-value:0.19269999861717224, distributions are identical
# For week 256: mmd:0.09574, p-value:0.2587999999523163, distributions are identical
# For week 257: mmd:0.09732, p-value:0.22819998860359192, distributions are identical
# For week 258: mmd:0.17118, p-value:0.001999999862164259, distributions are distinct
# For week 259: mmd:0.11018, p-value:0.11469999700784683, distributions are identical
# For week 260: mmd:0.13416, p-value:0.027799999341368675, distributions are distinct
# For week 261: mmd:0.14945, p-value:0.012399999424815178, distributions are distinct
# For week 262: mmd:0.08869, p-value:0.34700000286102295, distributions are identical
# For week 263: mmd:0.08763, p-value:0.37610000371932983, distributions are identical
# For week 264: mmd:0.09417, p-value:0.2800999879837036, distributions are identical
# For week 265: mmd:0.16416, p-value:0.0015999999595806003, distributions are distinct
# For week 266: mmd:0.10597, p-value:0.13120000064373016, distributions are identical
# For week 267: mmd:0.09646, p-value:0.24390000104904175, distributions are identical
# For week 268: mmd:0.11189, p-value:0.1087999939918518, distributions are identical
# For week 269: mmd:0.08344, p-value:0.4447000026702881, distributions are identical
# For week 270: mmd:0.08791, p-value:0.3571999967098236, distributions are identical
# For week 271: mmd:0.11548, p-value:0.08190000057220459, distributions are identical
# For week 272: mmd:0.23048, p-value:0.0, distributions are distinct
# For week 273: mmd:0.11136, p-value:0.10319999605417252, distributions are identical
# For week 274: mmd:0.12124, p-value:0.06350000202655792, distributions are identical
# For week 275: mmd:0.08886, p-value:0.3568999767303467, distributions are identical
# For week 276: mmd:0.08465, p-value:0.4301999807357788, distributions are identical
# For week 277: mmd:0.11141, p-value:0.1143999993801117, distributions are identical
# For week 278: mmd:0.10862, p-value:0.12889999151229858, distributions are identical
# For week 279: mmd:0.18956, p-value:0.0004999999655410647, distributions are distinct
# For week 280: mmd:0.10530, p-value:0.1542000025510788, distributions are identical
# For week 281: mmd:0.09774, p-value:0.2248999923467636, distributions are identical
# For week 282: mmd:0.11804, p-value:0.07090000063180923, distributions are identical
# For week 283: mmd:0.13312, p-value:0.029199998825788498, distributions are distinct
# For week 284: mmd:0.11248, p-value:0.10649999976158142, distributions are identical
# For week 285: mmd:0.09519, p-value:0.2628999948501587, distributions are identical
# For week 286: mmd:0.14001, p-value:0.02709999866783619, distributions are distinct
# For week 287: mmd:0.08690, p-value:0.3822000026702881, distributions are identical
# For week 288: mmd:0.09504, p-value:0.24929998815059662, distributions are identical
# For week 289: mmd:0.11852, p-value:0.07400000095367432, distributions are identical
# For week 290: mmd:0.10537, p-value:0.14949999749660492, distributions are identical
# For week 291: mmd:0.12770, p-value:0.03879999741911888, distributions are distinct
# For week 292: mmd:0.12104, p-value:0.05929999798536301, distributions are identical
# For week 293: mmd:0.17925, p-value:0.0015999999595806003, distributions are distinct
# For week 294: mmd:0.13593, p-value:0.020399998873472214, distributions are distinct
# For week 295: mmd:0.12687, p-value:0.041600000113248825, distributions are distinct
# For week 296: mmd:0.09147, p-value:0.31929999589920044, distributions are identical
# For week 297: mmd:0.08355, p-value:0.44739997386932373, distributions are identical
# For week 298: mmd:0.09667, p-value:0.24939998984336853, distributions are identical
# For week 299: mmd:0.12235, p-value:0.05810000002384186, distributions are identical
# For week 300: mmd:0.18639, p-value:0.0009999999310821295, distributions are distinct
# For week 301: mmd:0.11068, p-value:0.11659999936819077, distributions are identical
# For week 302: mmd:0.09588, p-value:0.2620999813079834, distributions are identical
# For week 303: mmd:0.10316, p-value:0.16869999468326569, distributions are identical
# For week 304: mmd:0.08156, p-value:0.5018999576568604, distributions are identical
# For week 305: mmd:0.09243, p-value:0.3050000071525574, distributions are identical
# For week 306: mmd:0.09911, p-value:0.20729999244213104, distributions are identical
# For week 307: mmd:0.16752, p-value:0.0050999997183680534, distributions are distinct
# For week 308: mmd:0.10024, p-value:0.19059999287128448, distributions are identical
# For week 309: mmd:0.10005, p-value:0.1867000013589859, distributions are identical
# For week 310: mmd:0.09330, p-value:0.2830999791622162, distributions are identical
# For week 311: mmd:0.09328, p-value:0.28189998865127563, distributions are identical
# For week 312: mmd:0.09474, p-value:0.26100000739097595, distributions are identical
# For week 313: mmd:0.09832, p-value:0.2198999971151352, distributions are identical
# For week 314: mmd:0.15302, p-value:0.012199999764561653, distributions are distinct
# For week 315: mmd:0.07911, p-value:0.5444999933242798, distributions are identical
# For week 316: mmd:0.08192, p-value:0.4869000017642975, distributions are identical
# For week 317: mmd:0.08031, p-value:0.517799973487854, distributions are identical
# For week 318: mmd:0.07997, p-value:0.5245000123977661, distributions are identical
# For week 319: mmd:0.09154, p-value:0.30889999866485596, distributions are identical
# For week 320: mmd:0.08967, p-value:0.3366999924182892, distributions are identical
# For week 321: mmd:0.15186, p-value:0.010999999940395355, distributions are distinct
# For week 322: mmd:0.10549, p-value:0.142099991440773, distributions are identical
# For week 323: mmd:0.09535, p-value:0.2604999840259552, distributions are identical
# For week 324: mmd:0.08715, p-value:0.38449999690055847, distributions are identical
# For week 325: mmd:0.08045, p-value:0.5159000158309937, distributions are identical
# For week 326: mmd:0.10276, p-value:0.17499999701976776, distributions are identical
# For week 327: mmd:0.11209, p-value:0.10939999669790268, distributions are identical
# For week 328: mmd:0.15607, p-value:0.009099999442696571, distributions are distinct
# For week 329: mmd:0.09058, p-value:0.3278999924659729, distributions are identical
# For week 330: mmd:0.08393, p-value:0.4414999783039093, distributions are identical
# For week 331: mmd:0.07894, p-value:0.5455999970436096, distributions are identical
# For week 332: mmd:0.08202, p-value:0.4901999831199646, distributions are identical
# For week 333: mmd:0.09938, p-value:0.21549999713897705, distributions are identical
# For week 334: mmd:0.08480, p-value:0.4188999831676483, distributions are identical
# For week 335: mmd:0.13374, p-value:0.03629999980330467, distributions are distinct
# For week 336: mmd:0.07832, p-value:0.5652999877929688, distributions are identical
# For week 337: mmd:0.07919, p-value:0.5530999898910522, distributions are identical
# For week 338: mmd:0.07876, p-value:0.5586000084877014, distributions are identical
# For week 339: mmd:0.07969, p-value:0.5321999788284302, distributions are identical
# For week 340: mmd:0.09195, p-value:0.296999990940094, distributions are identical
# For week 341: mmd:0.09190, p-value:0.30219998955726624, distributions are identical
# For week 342: mmd:0.13873, p-value:0.025699999183416367, distributions are distinct
# For week 343: mmd:0.08003, p-value:0.5327000021934509, distributions are identical
# For week 344: mmd:0.08642, p-value:0.3919999897480011, distributions are identical
# For week 345: mmd:0.08545, p-value:0.41189998388290405, distributions are identical
# For week 346: mmd:0.09020, p-value:0.32269999384880066, distributions are identical
# For week 347: mmd:0.10003, p-value:0.20639999210834503, distributions are identical
# For week 348: mmd:0.09142, p-value:0.3017999827861786, distributions are identical
# For week 349: mmd:0.13907, p-value:0.028699999675154686, distributions are distinct
# For week 350: mmd:0.07822, p-value:0.5734999775886536, distributions are identical
# For week 351: mmd:0.07819, p-value:0.5569999814033508, distributions are identical
# For week 352: mmd:0.08653, p-value:0.3887999951839447, distributions are identical
# For week 353: mmd:0.09562, p-value:0.2459999918937683, distributions are identical
# For week 354: mmd:0.10315, p-value:0.1776999980211258, distributions are identical
# For week 355: mmd:0.09259, p-value:0.29729998111724854, distributions are identical
# For week 356: mmd:0.14535, p-value:0.02019999921321869, distributions are distinct
# For week 357: mmd:0.08333, p-value:0.4520999789237976, distributions are identical
# For week 358: mmd:0.08467, p-value:0.4396999776363373, distributions are identical
# For week 359: mmd:0.09113, p-value:0.3164999783039093, distributions are identical
# For week 360: mmd:0.09469, p-value:0.2651999890804291, distributions are identical
# For week 361: mmd:0.11814, p-value:0.0810999944806099, distributions are identical
# For week 362: mmd:0.09926, p-value:0.2126999944448471, distributions are identical
# For week 363: mmd:0.15265, p-value:0.01549999974668026, distributions are distinct

# %%
mmd = [result[1][0].item() for result in results]
pval = [result[1][1].item() for result in results]
segment = [result[0] for result in results]
df_results = pd.DataFrame({'MMD':mmd, 'P_value':pval})
df_results.index.name = SEGMENT_NAME

# %%
df_results.to_csv(SAVE_DIR + SAVE_NAME + '.csv', 
                  #index=0,
                  )
