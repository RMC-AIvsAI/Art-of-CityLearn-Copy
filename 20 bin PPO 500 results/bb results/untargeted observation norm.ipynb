# %%
import numpy as np
import pandas as pd
#from numba import njit, prange

# %% [markdown]
# Norms for the untargeted bb attack

# %%
df_clean = pd.read_csv("clean obs.csv")
df_adv = pd.read_csv("bb obs.csv")

# %%
df_diff = df_adv - df_clean
adv_norms = df_diff.apply(lambda row: np.linalg.norm(row, ord=np.inf), axis='columns')

# %%
adv_norms.describe()
# Out:
# count    8759.000000
# mean        0.026835
# std         0.034024
# min         0.000001
# 25%         0.006319
# 50%         0.015610
# 75%         0.034521
# max         0.406255
# dtype: float64

# %% [markdown]
# try setting xlim to 0

# %%
adv_norms.plot.kde(grid=True, 
                   xticks=np.arange(start=adv_norms.min(), stop=adv_norms.max(), step=0.01),
                   figsize=(20,12),
                   xlim=[adv_norms.min(),adv_norms.max()],
                   )
# Out:
# <Axes: ylabel='Density'>

# %%
adv_norms.to_frame().describe()
# Out:
#                  0
# count  8759.000000
# mean      0.026835
# std       0.034024
# min       0.000001
# 25%       0.006319
# 50%       0.015610
# 75%       0.034521
# max       0.406255
