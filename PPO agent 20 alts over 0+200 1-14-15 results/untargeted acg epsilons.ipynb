# %%
import pandas as pd

# %matplotlib inline

# %%
s_eps = pd.read_csv('epsilons.csv',
                    index_col=0)

# %%
s_eps.describe()
# Out:
#        dynamic_untargeted_acg
# count             8750.000000
# mean                 0.020578
# std                  0.012744
# min                  0.010000
# 25%                  0.010000
# 50%                  0.010000
# 75%                  0.030000
# max                  0.070000

# %%
s_eps.value_counts()
# Out:
# dynamic_untargeted_acg
# 0.01                      4746
# 0.03                      3442
# 0.05                       500
# 0.07                        62
# dtype: int64

# %% [markdown]
# Comapred to the PPO trained for 500 episodes, the asr was 3% points lower and the required epsilon increased

# %%
s_eps.value_counts().plot.pie(autopct='%1.1f%%', 
                              ylabel='Epsilon',
                              title=f'Epsilon values for Dynamic Distortion ACG attack on ATLA Agent')
# Out:
# <Axes: title={'center': 'Epsilon values for Dynamic Distortion ACG attack on ATLA Agent'}, ylabel='Epsilon'>
