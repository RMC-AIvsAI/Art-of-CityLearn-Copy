# %% [markdown]
# Combine all figs into one plot

# %%
import pandas as pd
import numpy as np

# %%
df_mae = pd.read_csv(r'Karla\3-26-5 PPOc Karla results\imitator (best) fgm eps vs asr\MAE for varied epsilons bifurcation DL loss.csv',
                     index_col=0,
                     header=0)
df_mae.index = df_mae.index.to_series().round(3)
df_mae.columns = ['500_Training_Episodes_Plus_Bifurcation_Layer',]

# %%
df_mae.plot.line(ylabel='MAE',
                 xlabel='FGM Epsilons',
                 title='Comparison of MAEs and Perturbation Size for Immitator Snooping Attacks on Different Agents',
                 style=['b-.','b-','r-.','r-'],
                 )
# Out:
# <Axes: title={'center': 'Comparison of MAEs and Perturbation Size for Immitator Snooping Attacks on Different Agents'}, xlabel='FGM Epsilons', ylabel='MAE'>

# %%
df_kpi = pd.read_csv(r'Karla\3-26-5 PPOc Karla results\imitator (best) fgm eps vs asr\19 run KPIs bifurcation DL loss.csv',
                          index_col=0)
df_kpi.columns = df_kpi.columns.astype(float).to_series().round(3).astype(str)

# %%
df_kpi
# Out:
#                                            0.02      0.03      0.04      0.05  \
# cost_function
# annual_peak_average                    1.000000  1.000000  1.063309  1.122470
# carbon_emissions_total                 0.900903  0.933104  0.968246  1.012610
# cost_total                             0.835799  0.856705  0.887036  0.927121
# daily_one_minus_load_factor_average    1.000039  0.980415  0.965272  0.958430
# daily_peak_average                     0.927978  0.993053  1.069291  1.173023
# electricity_consumption_total          0.916968  0.949588  0.983609  1.026348
# monthly_one_minus_load_factor_average  0.985938  0.990946  0.986320  0.982582
# ramping_average                        1.145868  1.305664  1.459845  1.649855
# zero_net_energy                        1.084601  1.090130  1.095832  1.101513
#
#                                            0.06      0.07      0.08      0.09  \
# cost_function
# annual_peak_average                    1.184918  1.032421  1.191329  1.241201
# ...

# %%
electricity_consumption = pd.DataFrame()
electricity_consumption['500_Training_Episodes_Plus_Bifurication_Layer'] = df_kpi.loc['electricity_consumption_total'].transpose()
electricity_consumption.loc['0.00'] = [0.8809147062913397]
electricity_consumption.sort_index(inplace=True)

# %% [markdown]
# plot KPIs with ASRs/Epsilons

# %%
electricity_consumption.plot.line(
    ylabel='Total Electricity Consumption KPI',
    xlabel='FGM Epsilon',
    title='Electricity Consumption vs FGM Epsilon for Immitator Snooping Attack for Different Agents',
    style=['b-.','b-','r-.','r-'],
)
# Out:
# <Axes: title={'center': 'Electricity Consumption vs FGM Epsilon for Immitator Snooping Attack for Different Agents'}, xlabel='FGM Epsilon', ylabel='Total Electricity Consumption KPI'>

# %%
cost = pd.DataFrame()
cost['500_Training_Episodes_Plus_Bifurication_Layer'] = df_kpi.loc['cost_total'].transpose()
cost.loc['0.00'] = [0.798446427857767]
cost.sort_index(inplace=True)

# %%
cost.plot.line(
    ylabel='Total Electricity Cost KPI',
    xlabel='FGM Epsilon',
    title='Electricity Cost vs FGM Epsilon for Immitator Snooping Attack for Different Agents',
    style=['b-.','b-','r-.','r-'],
)
# Out:
# <Axes: title={'center': 'Electricity Cost vs FGM Epsilon for Immitator Snooping Attack for Different Agents'}, xlabel='FGM Epsilon', ylabel='Total Electricity Cost KPI'>

# %%
plot_kpis = ['electricity_consumption_total','cost_total','daily_peak_average','ramping_average']

# %%
df_kpi_plot = df_kpi.loc[plot_kpis].transpose()
df_kpi_plot.loc['0.00'] = [0.8809147062913397,0.798446427857767,0.8986220662900906,1.088548505415332]
df_kpi_plot.sort_index(inplace=True)

# %%
df_kpi_plot.plot.line(
    ylabel='Normalized KPI',
    xlabel='FGM Epsilon',
    title='Electricity Cost and Comsumption vs FGM Epsilon for Immitator Snooping Attack on SAC Agent',
    #style=['b-.','b-','r-.','r-'],
)
# Out:
# <Axes: title={'center': 'Electricity Cost and Comsumption vs FGM Epsilon for Immitator Snooping Attack on SAC Agent'}, xlabel='FGM Epsilon', ylabel='Normalized KPI'>

# %%
df_dkpi = pd.read_csv(r'20 bin PPO 500 results\multi eps vs asr for imitator FGM\19 run KPIs bin layer DL loss.csv',
                          index_col=0)
df_dkpi.columns = df_dkpi.columns.astype(float).to_series().round(3).astype(str)

# %%
df_dkpi_plot = df_dkpi.loc[plot_kpis].transpose()
df_dkpi_plot.loc['0.00'] = [0.8791079206961654,0.7878032417196625,0.8986220662900906,1.0937492364594632]
df_dkpi_plot.sort_index(inplace=True)

# %%
ax = pd.concat([df_kpi_plot,df_dkpi_plot], axis='columns').plot.line(
    ylabel='Normalized KPI',
    xlabel='FGM Epsilon',
    title='KPIs vs Bifurcated FGM Epsilon for \n Imitator Snooping Attack on Continuous and Discrete PPO Agents',
    style=['b-.','r-.','g-.','c-.','b-','r-','g-','c-'],
    xticks = np.arange(21, step=2),
    figsize=(10,5),
)
ax.legend(['Continuous PPO Electricity Consumption',
           'Continuous PPO Electricity Cost',
           'Continuous PPO Daily Peak',
           'Continuous PPO Ramping',
           'Discrete PPO Electricity Consumption',
           'Discrete PPO Electricity Cost',
           'Discrete PPO Daily Peak',
           'Discrete PPO Ramping',
           ])
