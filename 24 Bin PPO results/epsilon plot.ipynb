# %%
import pandas as pd

# %%
pds_eps = pd.read_csv('Epsilons.csv', index_col=0)

# %%
pds_eps.value_counts()
# Out:
# 0
# 0.01    4399
# 0.03    3601
# 0.05     649
# 0.07      97
# dtype: int64

# %%
pds_eps.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
pds_eps.value_counts().plot.pie(ylabel='distortion size', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='distortion size'>
